# %%
import datetime
import hashlib


class Block:
    blockNo = 0
    data = None
    next = None
    hash = 0
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
            str(self.nonce).encode('utf-8') +
            str(self.data).encode('utf-8') +
            str(self.previous_hash).encode('utf-8') +
            str(self.timestamp).encode('utf-8') +
            str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlock No: " + str(self.blockNo) + "\nBlock Data: " + str(
            self.data) + "\nBlock Next: " + str(self.next) + "\nBlock Previous Hash: " + str(
            self.previous_hash) + "\nBlock Timestamp: " + str(self.timestamp)


class Blockchain:
    diff = 20
    maxNonce = 2 ** 32
    target = 2 ** (256 - diff)

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):
        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1


blockchain = Blockchain()

for n in range(2):
    blockchain.mine(Block("Block" + str(n + 1)))

while blockchain.head is not None:
    print("8_siddesh \n")
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block No: 1
# Block Data: Block1
# Block Next: None
# Block Previous Hash: 4d947eb5a7eab5601fc463bd77bb12336324b27217d783d4234b163b9754d61e
# Block Timestamp: 2023-06-27 16:50:14.226255
# Block Hash: 378d01aab7626a79bfee2ecd288377419d1728afd5ad754fcb58359cdd83ebb5
# Block No: 2
# Block Data: Block2
# Block Next: None
# Block Previous Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block Timestamp: 2023-06-27 16:50:14.226255
# 8_siddesh
#
# Block Hash: 4d947eb5a7eab5601fc463bd77bb12336324b27217d783d4234b163b9754d61e
# Block No: 0
# Block Data: Genesis
# Block Next: Block Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block No: 1
# Block Data: Block1
# Block Next: Block Hash: 378d01aab7626a79bfee2ecd288377419d1728afd5ad754fcb58359cdd83ebb5
# Block No: 2
# Block Data: Block2
# Block Next: None
# Block Previous Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block Timestamp: 2023-06-27 16:50:14.226255
# Block Previous Hash: 4d947eb5a7eab5601fc463bd77bb12336324b27217d783d4234b163b9754d61e
# Block Timestamp: 2023-06-27 16:50:14.226255
# Block Previous Hash: 0
# Block Timestamp: 2023-06-27 16:50:14.226255
# 8_siddesh
#
# Block Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block No: 1
# Block Data: Block1
# Block Next: Block Hash: 378d01aab7626a79bfee2ecd288377419d1728afd5ad754fcb58359cdd83ebb5
# Block No: 2
# Block Data: Block2
# Block Next: None
# Block Previous Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block Timestamp: 2023-06-27 16:50:14.226255
# Block Previous Hash: 4d947eb5a7eab5601fc463bd77bb12336324b27217d783d4234b163b9754d61e
# Block Timestamp: 2023-06-27 16:50:14.226255
# 8_siddesh
#
# Block Hash: 378d01aab7626a79bfee2ecd288377419d1728afd5ad754fcb58359cdd83ebb5
# Block No: 2
# Block Data: Block2
# Block Next: None
# Block Previous Hash: e8a0b650bd4a0c5cd4d3db06a2d72f5cb131e3a5aeda0243fedf84b3eb65af90
# Block Timestamp: 2023-06-27 16:50:14.226255
