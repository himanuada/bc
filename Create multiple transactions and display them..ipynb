# %%
blockchain = []

print("Shruti\n")

def get_last_value():
    return blockchain[-1]

def add_value(sender, recipient, amount=1.0):
    transaction = {
        "sender": sender,
        "recipient": recipient,
        "amount": amount
    }
    blockchain.append(transaction)

def get_transaction_value():
    tx_sender = input("Enter the sender: ")
    tx_recipient = input("Enter the recipient of the transaction: ")
    tx_amount = float(input("Enter the amount of the transaction: "))
    return tx_sender, tx_recipient, tx_amount

def print_block():
    for block in blockchain:
        print("Shruti\n")
        print("Here is your block")
        print(block)

again = True
while again:
    tx = get_transaction_value()
    s, r, a = tx
    add_value(s, r, a)
    print(blockchain)
    more = input("Add more block Y/N? ")
    if more.lower() == "y":
        again = True
    else:
        again = False

print(blockchain)
# Out:
# Shruti
#
# Enter the sender: sourish
# Enter the recipient of the transaction: sakshi
# Enter the amount of the transaction: 500
# [{'sender': 'sourish', 'recipient': 'sakshi', 'amount': 500.0}]
# Add more block Y/N? Y
# Enter the sender: amit
# Enter the recipient of the transaction: sourish
# Enter the amount of the transaction: 600
# [{'sender': 'sourish', 'recipient': 'sakshi', 'amount': 500.0}, {'sender': 'amit', 'recipient': 'sourish', 'amount': 600.0}]
# Add more block Y/N? N
# [{'sender': 'sourish', 'recipient': 'sakshi', 'amount': 500.0}, {'sender': 'amit', 'recipient': 'sourish', 'amount': 600.0}]
